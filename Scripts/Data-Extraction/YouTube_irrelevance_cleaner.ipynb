# %%
import pandas as pd
import csv
from tqdm import tqdm

# %%
video_data = pd.read_csv("../../Data/Raw/test_youtube_videos.csv")

# %%
new_video_data = video_data.loc[video_data['title'].str.contains("test|wtc", case=False)].drop_duplicates()
# Out:
#         video_id                                              title  \
# 0    gTo-lPOGPdg  Australia v India | WTC23 Final | Match Highli...
# 3    B3JZZThHKA4  Less than 10 months to go for the #WTC25 Final...
# 4    I7fqF6j_CJI  Australia’s victorious WTC23 campaign | The Te...
# 5    MbKhGIPRvGI  Australian young gun Sam Konstas put to the te...
# 6    ohKPrdpbaaA  The King of Yorkers Jasprit Bumrah is now the ...
# 12   0DWyoFEcfzQ  Consistency is key for Nathan Lyon on the road...
# 20   xsiWVrjg1i0  Australia crowned No.1 Test team in Annual Ran...
# 25   SFALFSp4mgQ  Usman Khawaja wins the ICC Men&#39;s Test Cric...
# 26   GYQOYShgtLw  Usman Khawaja compares current Australian Test...
# 29   W5Cq-lIWIt0  Boland v Kohli, WTC23 Final. The next edition ...
# 34   AEe2MRc8rcg  &quot;For me, that&#39;s the World Cup&quot;: ...
# 42   1zKFpTNpd_0  Usman Khawaja compares Australia&#39;s Test te...
# 54   n1DI_a0o5DM  Ricky Ponting talks about Jason Gillespie’s ap...
# 86   80kTU6Q7zKo  It&#39;s a fiery contest happening in Benoni 🥵...
# 93   Yo4Mz9vsdV8  Ponting lauds Ashwin ahead of his 100th Test 🌟...
# 224  VQpTVVsNHQs  Glenn Maxwell produces one of the greatest ODI...
# 278  pdIQyTMdI8A  IT&#39;S HAPPENING 🤩 The ICC #WTC25 Final will...
#
#              published_at
# 0    2024-02-13T03:00:17Z
# 3    2024-09-04T17:20:24Z
# 4    2024-05-07T21:10:00Z
# 5    2024-01-28T04:00:06Z
# 6    2024-02-07T17:19:55Z
# 12   2024-09-04T06:52:19Z
# 20   2024-05-04T04:34:26Z
# 25   2024-01-27T12:23:22Z
# 26   2024-05-20T06:07:10Z
# 29   2024-09-07T04:30:21Z
# 34   2024-09-04T04:43:43Z
# 42   2024-05-21T01:30:24Z
# 54   2024-08-12T09:40:20Z
# 86   2024-02-06T12:50:45Z
# 93   2024-03-06T17:08:53Z
# 224  2024-02-11T04:08:33Z
# 278  2024-09-03T10:00:00Z
